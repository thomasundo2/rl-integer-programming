# %% [markdown]
# <a href="https://colab.research.google.com/github/thomasundo2/rl-integer-programming/blob/gpu/run_rl_integer_programming.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Installation and setup
# ---
# First, ensure that the repo is copied into the runtime on the "Files" tab to the right. Run the following code to install the necessary requirements for this project.
#
# Whenever starting a new run, factory reset the runtime and run the below.

# %%
# %load_ext autoreload

# %%
# %autoreload 2

# %%
# !which python # should return /usr/local/bin/python
# !python --version
# Out:
# /usr/local/bin/python
# Python 3.7.1

# %%
# !echo $PYTHONPATH
# %env PYTHONPATH=
# Out:
# env: PYTHONPATH=

# %%
# %%bash
# MINICONDA_INSTALLER_SCRIPT=Miniconda3-4.5.4-Linux-x86_64.sh
# MINICONDA_PREFIX=/usr/local
# wget https://repo.continuum.io/miniconda/$MINICONDA_INSTALLER_SCRIPT
# chmod +x $MINICONDA_INSTALLER_SCRIPT
# ./$MINICONDA_INSTALLER_SCRIPT -b -f -p $MINICONDA_PREFIX
# Out:
# PREFIX=/usr/local
# installing: python-3.6.5-hc3d631a_2 ...
# installing: ca-certificates-2018.03.07-0 ...
# installing: conda-env-2.6.0-h36134e3_1 ...
# installing: libgcc-ng-7.2.0-hdf63c60_3 ...
# installing: libstdcxx-ng-7.2.0-hdf63c60_3 ...
# installing: libffi-3.2.1-hd88cf55_4 ...
# installing: ncurses-6.1-hf484d3e_0 ...
# installing: openssl-1.0.2o-h20670df_0 ...
# installing: tk-8.6.7-hc745277_3 ...
# installing: xz-5.2.4-h14c3975_4 ...
# installing: yaml-0.1.7-had09818_2 ...
# installing: zlib-1.2.11-ha838bed_2 ...
# installing: libedit-3.1.20170329-h6b74fdf_2 ...
# installing: readline-7.0-ha6073c6_4 ...
# installing: sqlite-3.23.1-he433501_0 ...
# installing: asn1crypto-0.24.0-py36_0 ...
# installing: certifi-2018.4.16-py36_0 ...
# installing: chardet-3.0.4-py36h0f667ec_1 ...
# installing: idna-2.6-py36h82fb2a8_1 ...
# installing: pycosat-0.6.3-py36h0a5515d_0 ...
# installing: pycparser-2.18-py36hf9f622e_1 ...
# installing: pysocks-1.6.8-py36_0 ...
# ...

# %%
# !which conda
# !conda --version
# Out:
# /usr/local/bin/conda
# conda 4.5.4

# %%
import sys
_ = (sys.path
        .append("/usr/local/lib/python3.7/site-packages"))

# %% [markdown]
# Type yes below in the output of the cell

# %%
# !conda install -c gurobi --no-deps gurobi  _libgcc_mutex ld_impl_linux-64
# Out:
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.5.4
#   latest version: 4.10.1
#
# Please update conda by running
#
#     $ conda update -n base conda
#
#
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - _libgcc_mutex
#     - gurobi
#     - ld_impl_linux-64
#
#
# The following packages will be UPDATED:
#
#     gurobi: 9.1.1-py37_0 gurobi --> 9.1.1-py36_0 gurobi
#
# Proceed ([y]/n)? y
#
# done
# done
# done

# %%
# !which python # should return /usr/local/bin/python
# !python --version # Python 3.7
# Out:
# /usr/local/bin/python
# Python 3.6.5 :: Anaconda, Inc.

# %%
# request key on this site: https://www.gurobi.com/downloads/free-academic-license/
# !grbgetkey 30c2d8f0-a1ff-11eb-bd6d-0242ac120002
# Out:
# info  : grbgetkey version , build v9.1.1rc0
# info  : Contacting Gurobi license server...
# info  : License file for license ID 617664 was successfully retrieved
# info  : License expires at the end of the day on 2021-06-19
# info  : Saving license file...
#
# In which directory would you like to store the Gurobi license file?
# [hit Enter to store it in /opt/gurobi]:
#
# A license file already exists in '/opt/gurobi/gurobi.lic'
# Continue? [Y/n] Y
#
# info  : License 617664 written to file /opt/gurobi/gurobi.lic

# %%
# !python --version
# Out:
# Python 3.6.5 :: Anaconda, Inc.

# %%
# !unzip learn2cut_gym_gpu.zip
# Out:
# unzip:  cannot find or open learn2cut_gym_gpu.zip, learn2cut_gym_gpu.zip.zip or learn2cut_gym_gpu.zip.ZIP.

# %%
# unpack folder
# !mv learn2cut_gym_gpu/* .
# Out:
# mv: cannot stat 'learn2cut_gym_gpu/*': No such file or directory

# %%
import run_ppo
run_ppo.main()
# Out:
# Running on cpu
# loading training instances, dir instances/train_10_n60_m60 idx 0
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-35-06dbefd6e4b9> in <module>()
#       1 import run_ppo
# ----> 2 run_ppo.main()
#
# /content/run_ppo.py in main()
#      81                 critic_params,
#      82                 rnd_params,
# ---> 83                 **hyperparams
#      84                 )
#      85
#
# /content/run_ppo.py in run_ppo(env_config, policy_params, critic_params, rnd_params, iterations, num_processes, num_trajs_per_process, gamma, intrinsic_gamma)
#      33     rrecord = []
#      34
# ---> 35     env = make_multiple_env(**env_config)
#      36     ppo_ac = build_ppo(policy_params, critic_params)
#      37     rnd = build_rnd(rnd_params)
#
# /content/gymenv_v2.py in make_multiple_env(load_dir, idx_list, timelimit, reward_type)
# ...

# %%
rm *.py
